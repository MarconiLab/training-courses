# %% [markdown]
# ### ICTP-IAEA WORKSHOOP ON ENVIRONMENTAL MAPPING: Mobilising	Trust	in Measurements	and	Engaging Scientific Citizenry, Trieste, March 2017
# ---

# %% [markdown]
# # II. Exploratory Data Analysis with Pandas

# %%
# This ensures visualizations are plotted inside the notebook
#%matplotlib inline

import os              # This provides several system utilities
import pandas as pd    # This is the workhorse of data munging in Python
import matplotlib.pyplot as plt
import seaborn as sns  # This allows us to easily and beautifully plot

# %%
f = 'data/safecast_subset.csv'    # Path to file containing the table
df = pd.read_csv(f)    # Read the table in

# %%
df.head()
# Out:
#          id  value captured_at   latitude   longitude
# 0  15500999  20283  2012-01-18  37.414865  141.028495
# 1  15500998  19713  2012-01-18  37.414992  141.028215
# 2  15501000  20667  2012-01-18  37.414817  141.028568
# 3  15501002  21206  2012-01-18  37.414787  141.028612
# 4  15501003  21220  2012-01-18  37.414777  141.028622

# %%
df.shape
# Out:
# (20000, 5)

# %%
df.tail()
# Out:
#              id  value captured_at   latitude   longitude
# 19995  15556434    105  2012-02-11  37.493222  141.001600
# 19996  15556570     83  2012-02-11  37.493218  141.001585
# 19997  17580599     83  2012-02-11  37.493218  141.001585
# 19998  15556435    108  2012-02-11  37.493223  141.001602
# 19999  17580062    108  2012-02-11  37.493223  141.001602

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 5 columns):
# id             20000 non-null int64
# value          20000 non-null int64
# captured_at    20000 non-null object
# latitude       20000 non-null float64
# longitude      20000 non-null float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 781.3+ KB

# %%
df.describe()
# Out:
#                  id         value      latitude     longitude
# count  2.000000e+04  20000.000000  20000.000000  20000.000000
# mean   1.516094e+07   1960.759100     37.427714    140.999617
# std    1.055228e+06   2600.394336      0.048294      0.021810
# min    1.396153e+07     26.000000     37.347060    140.943918
# 25%    1.431688e+07    268.000000     37.370278    140.994348
# 50%    1.489503e+07   1324.000000     37.428858    141.001598
# 75%    1.550091e+07   2239.250000     37.479326    141.009709
# max    1.782908e+07  24282.000000     37.495978    141.041357

# %%
df['value'].min()
# Out:
# 26

# %%
df['value'].max()
# Out:
# 24282

# %%
df['value'].std()
# Out:
# 2600.3943357887611

# %%
df[['longitude', 'latitude', 'value']]
# Out:
#         longitude   latitude  value
# 0      141.028495  37.414865  20283
# 1      141.028215  37.414992  19713
# 2      141.028568  37.414817  20667
# 3      141.028612  37.414787  21206
# 4      141.028622  37.414777  21220
# 5      141.028588  37.414792  20916
# 6      141.028643  37.414760  20809
# 7      141.028720  37.414698  20432
# 8      141.028720  37.414697  20394
# 9      141.028720  37.414697  20504
# 10     141.028720  37.414697  20243
# 11     141.028720  37.414697  20339
# 12     141.028717  37.414697  20717
# 13     141.028720  37.414695  20629
# 14     141.028720  37.414695  20647
# 15     141.028720  37.414695  20630
# 16     141.028718  37.414695  20629
# 17     141.028718  37.414695  20670
# 18     141.028718  37.414695  20239
# 19     141.028718  37.414695  20614
# 20     141.028718  37.414695  20585
# 21     141.028720  37.414693  20250
# 22     141.028715  37.414695  20608
# 23     141.028718  37.414693  20236
# 24     141.028703  37.414700  19133
# ...

# %%
df['value'] > 20000
# Out:
# 0         True
# 1        False
# 2         True
# 3         True
# 4         True
# 5         True
# 6         True
# 7         True
# 8         True
# 9         True
# 10        True
# 11        True
# 12        True
# 13        True
# 14        True
# 15        True
# 16        True
# 17        True
# 18        True
# 19        True
# 20        True
# 21        True
# 22        True
# 23        True
# 24       False
# 25        True
# 26        True
# 27        True
# 28       False
# 29        True
#          ...
# 19970    False
# 19971    False
# 19972    False
# 19973    False
# 19974    False
# 19975    False
# 19976    False
# 19977    False
# 19978    False
# 19979    False
# 19980    False
# 19981    False
# 19982    False
# 19983    False
# 19984    False
# 19985    False
# 19986    False
# 19987    False
# 19988    False
# 19989    False
# 19990    False
# 19991    False
# 19992    False
# 19993    False
# 19994    False
# 19995    False
# 19996    False
# ...

# %%
df[df['value'] > 20000] # df['value'] > 20000 expression is called a 'mask'
# Out:
#            id  value captured_at   latitude   longitude
# 0    15500999  20283  2012-01-18  37.414865  141.028495
# 2    15501000  20667  2012-01-18  37.414817  141.028568
# 3    15501002  21206  2012-01-18  37.414787  141.028612
# 4    15501003  21220  2012-01-18  37.414777  141.028622
# 5    15501001  20916  2012-01-18  37.414792  141.028588
# 6    15501004  20809  2012-01-18  37.414760  141.028643
# 7    15501063  20432  2012-01-18  37.414698  141.028720
# 8    15501064  20394  2012-01-18  37.414697  141.028720
# 9    15501062  20504  2012-01-18  37.414697  141.028720
# 10   15501066  20243  2012-01-18  37.414697  141.028720
# 11   15501065  20339  2012-01-18  37.414697  141.028720
# 12   15501054  20717  2012-01-18  37.414697  141.028717
# 13   15501058  20629  2012-01-18  37.414695  141.028720
# 14   15501060  20647  2012-01-18  37.414695  141.028720
# 15   15501061  20630  2012-01-18  37.414695  141.028720
# 16   15501056  20629  2012-01-18  37.414695  141.028718
# ...

# %%
df.rename(columns={'value':'value_cpm'}, inplace=True)

# %%
df.head()
# Out:
#          id  value_cpm captured_at   latitude   longitude
# 0  15500999      20283  2012-01-18  37.414865  141.028495
# 1  15500998      19713  2012-01-18  37.414992  141.028215
# 2  15501000      20667  2012-01-18  37.414817  141.028568
# 3  15501002      21206  2012-01-18  37.414787  141.028612
# 4  15501003      21220  2012-01-18  37.414777  141.028622

# %%
df['value_usv_h'] = df['value_cpm']/334

# %%
df.head()
# Out:
#          id  value_cpm captured_at   latitude   longitude  value_usv_h
# 0  15500999      20283  2012-01-18  37.414865  141.028495    60.727545
# 1  15500998      19713  2012-01-18  37.414992  141.028215    59.020958
# 2  15501000      20667  2012-01-18  37.414817  141.028568    61.877246
# 3  15501002      21206  2012-01-18  37.414787  141.028612    63.491018
# 4  15501003      21220  2012-01-18  37.414777  141.028622    63.532934

# %%
# df.value_cpm = df.value_cpm.astype(int)

# %%
df.sort_values('value_cpm', ascending=False, inplace=True)

# %%
df.head()
# Out:
#            id  value_cpm captured_at   latitude   longitude  value_usv_h
# 120  15501194      24282  2012-01-18  37.415798  141.025828    72.700599
# 131  15501195      24210  2012-01-18  37.415953  141.025443    72.485030
# 144  15501196      23830  2012-01-18  37.416118  141.025027    71.347305
# 118  15501193      23702  2012-01-18  37.415620  141.026253    70.964072
# 115  15501192      23156  2012-01-18  37.415430  141.026660    69.329341

# %%
plt.figure(figsize=(16, 8))
sns.distplot(df['value_usv_h'], kde=False)

# %%
sns.jointplot(df['longitude'], df['latitude'], kind="hex", size=10)

# %%
df['latitude'].max()
# Out:
# 37.495978333332999

# %%
df['latitude'].min()

between 37.48 and 37.49 latitude
# Out:
# 37.347059999999999

# %% [markdown]
# ### Exercise

# %% [markdown]
# Plot an histogram of values (µSv/h) where latitude is between 37.48 and 37.49
#
# **Tip: Use logical operator 'and'**

# %% [markdown]
# ---
# <a rel="license" href="http://creativecommons.org/licenses/by-nc-sa/4.0/"><img alt="Creative Commons License" style="border-width:0" src="https://i.creativecommons.org/l/by-nc-sa/4.0/88x31.png" /></a><br />
#
# <span xmlns:dct="http://purl.org/dc/terms/" property="dct:title">Exploratory Data Analysis with Pandas</span> by <a xmlns:cc="http://creativecommons.org/ns#" href="http://darribas.org" property="cc:attributionName" rel="cc:attributionURL">Franck Albinet</a> licensed under a <a rel="license" href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International License</a>.
